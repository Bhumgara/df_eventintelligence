# %%
import requests
import pandas as pd
import dotenv
import os

# %%
dotenv.load_dotenv()

BASE_URL = "https://app.ticketmaster.com/discovery/v2"
CONSUMER_KEY = os.getenv("CONSUMER_KEY")
CONSUMER_SECRET = os.getenv("CONSUMER_SECRET")

# %%
def get_ticketmaster_data(endpoint, filters={}) -> pd.DataFrame:
    full_url = f"{BASE_URL}{endpoint}"
    query_params={'apikey': CONSUMER_KEY}
    query_params.update(filters)

    response = requests.get(full_url, params=query_params)

    print(f"Status Code: {response.status_code}")
    print(f"URL Used: {response.url}")

    data = response.json()

    df = pd.DataFrame(data)

    return df

# %%
endpoint = "/events.json"
kword_filters= {"keyword":"festival"}

df = get_ticketmaster_data(endpoint, filters=kword_filters)
df
# Out:
# Status Code: 200
# URL Used: https://app.ticketmaster.com/discovery/v2/events.json?apikey=TGzUiTz6ZRVqDBPAJftmo0CRJNLxmxOQ&keyword=festival
#                                                        _embedded  \
# events         [{'name': 'Disney On Ice presents Find Your He...
# first                                                        NaN
# self                                                         NaN
# next                                                         NaN
# last                                                         NaN
# size                                                         NaN
# totalElements                                                NaN
# totalPages                                                   NaN
# number                                                       NaN
#
#                                                           _links    page
# events                                                       NaN     NaN
# first          {'href': '/discovery/v2/events.json?keyword=fe...     NaN
# self           {'href': '/discovery/v2/events.json?keyword=fe...     NaN
# next           {'href': '/discovery/v2/events.json?keyword=fe...     NaN
# last           {'href': '/discovery/v2/events.json?keyword=fe...     NaN
# size                                                         NaN    20.0
# totalElements                                                NaN  3838.0
# totalPages                                                   NaN   192.0
# number                                                       NaN     0.0
